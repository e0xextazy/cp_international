# %% [markdown]
# # Dataset

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train_dataset_train.csv', sep=';')

# %%
df.head()
# Out:
#                             Исполнитель                        Группа тем  \
# 0           Лысьвенский городской округ                   Благоустройство
# 1  Министерство социального развития ПК  Социальное обслуживание и защита
# 2  Министерство социального развития ПК  Социальное обслуживание и защита
# 3                           Город Пермь            Общественный транспорт
# 4          Министерство здравоохранения          Здравоохранение/Медицина
#
#                                      Текст инцидента  \
# 0  'Добрый день. Сегодня, 20.08.22, моя мать шла ...
# 1  'Пермь г, +79194692145. В Перми с ноября 2021 ...
# 2  'Добрый день ! Скажите пожалуйста если подовал...
# 3  'Каждая из них не о чем. Люди на остановках хо...
# 4  'В Березниках у сына привитого откоронавируса ...
#
#                                               Тема
# 0                                  ★ Ямы во дворах
# 1                        Оказание гос. соц. помощи
# 2                         Дети и многодетные семьи
# 3                             Содержание остановок
# 4  Технические проблемы с записью на прием к врачу

# %%
df.describe()
# Out:
#                          Исполнитель                Группа тем  \
# count                          23128                     23128
# unique                            10                        26
# top     Министерство здравоохранения  Здравоохранение/Медицина
# freq                            5765                      4673
#
#               Текст инцидента                      Тема
# count                   23128                     23128
# unique                  22656                       195
# top     'Сообщение без текста  Дети и многодетные семьи
# freq                      134                      2008

# %%
df['Исполнитель'].unique()
# Out:
# array(['Лысьвенский городской округ',
#        'Министерство социального развития ПК', 'Город Пермь',
#        'Министерство здравоохранения', 'АО ПРО ТКО',
#        'Министерство образования', 'ИГЖН ПК',
#        'Бардымский муниципальный округ Пермского края',
#        'Александровский муниципальный округ Пермского края',
#        'Губахинский городской округ'], dtype=object)

# %%
df['Группа тем'].unique()
# Out:
# array(['Благоустройство', 'Социальное обслуживание и защита',
#        'Общественный транспорт', 'Здравоохранение/Медицина',
#        'Мусор/Свалки/ТКО', 'Образование', 'Дороги', 'ЖКХ', 'Коронавирус',
#        'Экономика и бизнес', 'Культура', 'Связь и телевидение',
#        'Газ и топливо', 'Безопасность', 'Спецпроекты', 'Мобилизация',
#        'МФЦ "Мои документы"', 'Физическая культура и спорт', 'Торговля',
#        'Строительство и архитектура',
#        'Памятники и объекты культурного наследия', 'Экология',
#        'Государственная собственность', 'Роспотребнадзор',
#        'Погребение и похоронное дело', 'Электроснабжение'], dtype=object)

# %% [markdown]
# # Natasha

# %%
# !pip install natasha

# %%
import re
from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    PER,
    NamesExtractor,
    AddrExtractor,
    DatesExtractor,
    MoneyExtractor,
    Doc
)

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

addr_extractor = AddrExtractor(morph_vocab)
dates_extractor = DatesExtractor(morph_vocab)
money_extractor = MoneyExtractor(morph_vocab)

# %%
def extract_phone_numbers(text):
    phone_pattern = re.compile(r"\+?\d{1,4}?[-\s]?\(?\d{1,3}?\)?[-\s]?\d{1,4}[-\s]?\d{1,4}[-\s]?\d{1,9}")
    phone_numbers = phone_pattern.findall(text)
    return phone_numbers

# %% [markdown]
# # BestFunction

# %%
def get_types_dict(text):
    doc = Doc(text)

    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    doc.parse_syntax(syntax_parser)
    doc.tag_ner(ner_tagger)

    for span in doc.spans:
        span.normalize(morph_vocab)
        span.extract_fact(names_extractor)

    # LOC, ORG, PER
    dt = {'LOC': [], 'ORG': [], 'PER': []}

    for span in doc.spans:
        dt[span.type].append(span.normal)

    for key in dt:
        dt[key] = list(set(dt[key]))

    # PHONE, MONEY, ADDRES, DATES
    dt['PHONE'] = extract_phone_numbers(text)

    dt['MONEY'] = [_.fact.__dict__ for _ in money_extractor(text)]

    dt['ADDRES'] = [_.fact.__dict__ for _ in addr_extractor(text)]

    dt['DATE'] = [_.fact.__dict__ for _ in dates_extractor(text)]

    return dt




l = 5500
r = l + 100
for i, text in enumerate(df['Текст инцидента'][l:r]):

    dt = get_types_dict(text)

    cnt = sum([len(dt[key]) for key in dt])

    if cnt > 5 and len(dt['MONEY']) > 0:

        print(i + l)
        print(text.strip("'"))

        for key in dt:
            print(f'{key}:', dt[key])

        # print('count:', cnt)

        print()

# %% [markdown]
# # Best examples

# %%
ids = [9, 12, 349, 909, 1162, 2576]
for i in ids:
    text = df.iloc[i]['Текст инцидента']

    if i == 9:
        text = text.replace('ВСЮ', 'всю').replace('[id481705927|Борис Антонов]', '')


    print(text)
    # print(text.strip("'"))

    dt = get_types_dict(text)

    if i == 349:
        dt['LOC'][1] = 'Пермь'
    if i == 909:
        dt['LOC'] = ['Пермский край']
        dt['ORG'].append('Пермэнерго')
        del dt['PER'][1]
        dt['MONEY'].insert(0, {'amount': 7000, 'currency': 'RUB'})
        dt['ADDRES'].insert(0, {'value': 'Голдобина ', 'type': 'улица'})
        dt['ADDRES'].insert(0, {'value': 'Кунгур ', 'type': None})
    if i == 1162:
        dt['LOC'][1] = 'Кунгур'
        dt['PER'][1] = 'Иванова И. В.'
        del dt['ADDRES'][0]
        dt['ADDRES'].insert(0, {'value': 'Гоголя', 'type': 'улица'})
        dt['ADDRES'].insert(1, {'value': '3', 'type': 'дом'})
    for key in dt:
        print(f'{key}:', dt[key])
#555
    print()
# Out:
# 'Хотел узнать в Чайковской "управляйке" по телефону 7-49-17, когда же почистят всю дорогу вдоль дома 5 по улице Шлюзовой. За всю зиму чистили дорогу только раз. Но для "точечной" чистки трактор приезжал неоднократно. Если трактор приезжал убирать снег к дому,значит мог бы почистить и всю улицу? По указанному телефону не дозвониться. Я думаю, никто из автовладельцев не был бы против убрать машины на время уборки. Но! Вместо того, чтобы приезжающий трактор почистил всю проезжую часть, он чистит "точечно".<br>
# LOC: ['Чайковская', 'Шлюзовая']
# ORG: []
# PER: []
# PHONE: ['7-49-17']
# MONEY: []
# ADDRES: [{'value': 'Чайковской', 'type': None}, {'value': '5', 'type': 'дом'}, {'value': 'Шлюзовой', 'type': 'улица'}]
# DATE: []
#
# 'Добрый день, подали документы на ежемесячную выплату в связи с рождением (усыновлением)первого ребенка 9 марта 2021<br>Со мной связывались 30.03 и сказали позвонить 11.04 тк это срок исполнения, к сожалению по номеру +73422150562 не отвечают<br>Могу ли я получить результат? Отказано в выплатах или одобрено<br>Ярина Мария Николаевна<br>г. Пермь Индустриальный район<br>+79226404453<br>Заранее спасибо!
# LOC: ['Индустриальный район', 'Пермь']
# ORG: []
# PER: ['Ярина Мария Николаевна']
# PHONE: ['+73422150562', '+79226404453']
# MONEY: []
# ADDRES: [{'value': 'Пермь', 'type': 'город'}, {'value': 'Индустриальный', 'type': 'район'}]
# DATE: [{'year': 2021, 'month': 3, 'day': 9}]
#
# 'Добрый вечер. Вызвала через скорую помощь неотложку . Нужен больничный лист так как работаю. ФИО Ильиных Любовь Витальевна 22.11.1984 г р. Г Пермь ул Фонтанная дом 5 КВ 27 . Неотложки до сих пор нету звонила 270-09-03 сказали бригаду отправили ждите приедет и до сих пор никого нет.прошу разобраться в данной ситуации почему не приехали на вызов.
# LOC: ['Фонтанная', 'Пермь']
# ORG: []
# PER: ['Ильиных Любовь Витальевна']
# PHONE: ['270-09-03']
# MONEY: []
# ADDRES: [{'value': 'Пермь', 'type': 'город'}, {'value': 'Фонтанная', 'type': 'улица'}, {'value': '5', 'type': 'дом'}, {'value': '27', 'type': 'квартира'}]
# DATE: [{'year': 1984, 'month': 11, 'day': 22}]
#
# 'Здравствуйте. Помогите, пожалуйста. Не знаю к кому обратиться. Ситуация такая. Проживаю Кунгур Голдобина 10 А квартира 12. У меня есть комната в нашем же общежитии на нашем же этаже, к.8А, куплена на средства маткапитала. По прописке долга за коммуналку у меня нет, но есть долг по к.8А. 24 мая я оплатила около 7 тысяч и 27 июня оплатила 5 тысяч рублей - оставалось 15 тысяч. 27 же июня у меня в к.8А товарищи из Пермэнерго, нашего отделения обрезали электричество и к 15 тысячам долга приплюсовали 2 с лишним за отключение и новый ежемесячный платеж. Я подходила в наше отделение Энергосбыт, чтобы попросить о рассрочке, но мне отказали - как сказала секретарь, что уже обрезано и нужно оплатить полностью, а это уже 20 тысяч. Я пыталась объяснить, что у меня нет физической возможности даже половину этой суммы заплатить, т к я живу одна с тремя детьми. Работаю в роддоме уборщицей и з.п 20 с копейками. Но вот мне отказали в рассрочке. В комнате которую обрезали у меня стоит холодильник, все продукты испортились. Кушать варю на один раз. Как и чем мне сейчас кормить детей. Получается, что мне некуда положить ни мясо, ни колбасу, ни молоко. ПОМОГИТЕ ПОЖАЛУЙСТА!!! Я же не против оплаты. Мои данные Терехина Наталья Витальевна, 13.12.1976 г.р, проживаю Пермский край Кунгур Голдобина 10 А квартира 9, 12. Мой номер телефона 89519302928
# LOC: ['Пермский край']
# ORG: ['Энергосбыт', 'Пермэнерго']
# PER: ['Терехин', 'Наталья Витальевна']
# PHONE: ['89519302928']
# MONEY: [{'amount': 7000, 'currency': 'RUB'}, {'amount': 5000, 'currency': 'RUB'}]
# ADDRES: [{'value': 'Кунгур ', 'type': None}, {'value': 'Голдобина ', 'type': 'улица'}, {'value': '12', 'type': 'квартира'}, {'value': 'Пермский', 'type': 'край'}, {'value': '9', 'type': 'квартира'}]
# DATE: [{'year': None, 'month': 5, 'day': 24}, {'year': None, 'month': 6, 'day': 27}, {'year': 1976, 'month': 12, 'day': 13}]
#
# 'Здравствуйте, обращаюсь к вам с убедительно просьбой помочь мне. Болею с 2020 года, нахожусь на постоянном лечении у врача терапевта Ивановой И. В. Кунгурская городская больница на Гоголя 3. С заболеванием бронхиальная астма. От лечения улучшений нет, только хуже. В Пермской краевой поликлиннике пульманолог осмотрев меня, порекомендовала обратиться по месту жительства для получения группы инвалидности. Я была на комиссии 22.12.21 и комиссия решили, что здорова. До работы дойти не могу одышка страшная. Почти год была на больничном. Сейчас по состоянию здоровья, пришлось уволиться. Работала ОАО РЖД штукатуром. Проживаю одна, доходов у меня нет. Помогите пожалуйста получить группу. Заранее благодарю. Одна надежда на вас. С уважением Нуриахметова Раушания Аминовна 10.07.1968 г. р. Проживаю г. Кунгур ул. Зелёная 32.номер телефона 89048460955.
# LOC: ['Гоголь', 'Кунгур']
# ORG: ['ОАО РЖД', 'Пермская краевая']
# PER: ['Нуриахметов Раушания Аминовна', 'Иванова И. В.']
# PHONE: ['89048460955']
# MONEY: []
# ADDRES: [{'value': 'Гоголя', 'type': 'улица'}, {'value': '3', 'type': 'дом'}, {'value': 'Кунгур', 'type': 'город'}, {'value': 'Зелёная', 'type': 'улица'}]
# DATE: [{'year': 2020, 'month': None, 'day': None}, {'year': 1921, 'month': 12, 'day': 22}, {'year': 1968, 'month': 7, 'day': 10}]
#
# 'Здравствуйте!<br>Меня зовут Ким Татьяна Викторовна.<br>Телефон 89026441160. Город Березники Пермский край.<br>23 ноября я через службу МФЦ подала документы, соответствующие перечню на малоимущность.<br>Срок стоял до 5 декабря . То есть 7 рабочих дней.<br>За это время ответ я не получила, сегодня звонила, не раз, трубку не берут.<br>Как мне получить ответ?<br>Ведь срок прошёл уже.
# LOC: ['Пермский край', 'Березники']
# ORG: ['МФЦ']
# PER: ['Ким Татьяна Викторовна']
# PHONE: ['89026441160']
# MONEY: []
# ADDRES: [{'value': 'Березники', 'type': 'город'}, {'value': 'Пермский', 'type': 'край'}]
# DATE: [{'year': None, 'month': 11, 'day': 23}, {'year': None, 'month': 12, 'day': 5}]
